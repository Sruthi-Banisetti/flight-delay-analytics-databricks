# %%
# %pip install kaggle

# %%
import os

os.environ["KAGGLE_USERNAME"] = "sruthibanisetti"
os.environ["KAGGLE_KEY"] = "d39a5b92422fe2927eb2e72515b7d2ec"

print("Kaggle credentials configured!")

# %%
spark.sql("""
CREATE SCHEMA IF NOT EXISTS workspace.flight_delay
""")

# %%
spark.sql("""
CREATE VOLUME IF NOT EXISTS workspace.flight_delay.flight_delay_data
""")

# %%
base_path = "/Volumes/workspace/flight_delay/flight_delay_data"
os.makedirs(base_path, exist_ok=True)

print(base_path)

# %%
# %sh
cd /Volumes/workspace/flight_delay/flight_delay_data
kaggle datasets download -d patrickzel/flight-delay-and-cancellation-dataset-2019-2023

# %%
# %sh
cd /Volumes/workspace/flight_delay/flight_delay_data
unzip flight-delay-and-cancellation-dataset-2019-2023.zip
rm flight-delay-and-cancellation-dataset-2019-2023.zip

# %%
# %restart_python

# %%
df_flight = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("/Volumes/workspace/flight_delay/flight_delay_data/*.csv")
)

df_flight.display()
